# %%
library(data.table)
library(FNN)
library(caret)
library(corrplot)
# Out:
# corrplot 0.84 loaded

# %%
fn <- '/Users/mbusch/OneDrive - Regis University/MSDS/680/MSDS680_ncg_S8W1_18/week1/data/heart.disease.data.clean.csv'
dt<- fread(fn)
head(dt)
# Out:
#   age sex cp trestbps chol cigs years fbs famhist restecg thalach exang thal
# 1 63  1   1  145      233  50   20    1   1       2       150     0     6
# 2 67  1   4  160      286  40   40    0   1       2       108     1     3
# 3 67  1   4  120      229  20   35    0   1       2       129     1     7
# 4 37  1   3  130      250   0    0    0   1       0       187     0     3
# 5 41  0   2  130      204   0    0    0   1       2       172     0     3
# 6 56  1   2  120      236  20   20    0   1       0       178     0     3
#   num
# 1 0
# 2 2
# 3 1
# 4 0
# 5 0
# 6 0

# %%
summary(dt)
# Out:
#       age             sex               cp           trestbps
#  Min.   :29.00   Min.   :0.0000   Min.   :1.000   Min.   : 94.0
#  1st Qu.:48.00   1st Qu.:0.0000   1st Qu.:3.000   1st Qu.:120.0
#  Median :55.00   Median :1.0000   Median :3.000   Median :130.0
#  Mean   :54.41   Mean   :0.6773   Mean   :3.163   Mean   :131.2
#  3rd Qu.:61.00   3rd Qu.:1.0000   3rd Qu.:4.000   3rd Qu.:140.0
#  Max.   :77.00   Max.   :1.0000   Max.   :4.000   Max.   :170.0
#       chol            cigs           years            fbs
#  Min.   :126.0   Min.   : 0.00   Min.   : 0.00   Min.   :0.0000
#  1st Qu.:213.0   1st Qu.: 0.00   1st Qu.: 0.00   1st Qu.:0.0000
#  Median :244.0   Median :11.98   Median :15.00   Median :0.0000
#  Mean   :247.7   Mean   :16.84   Mean   :15.35   Mean   :0.1489
#  3rd Qu.:277.0   3rd Qu.:30.00   3rd Qu.:30.00   3rd Qu.:0.0000
#  Max.   :360.0   Max.   :75.00   Max.   :54.00   Max.   :1.0000
#     famhist          restecg         thalach          exang
# ...

# %%
corrplot(cor(dt))
# Out:
# Plot with title “”

# %%
corrplot(cor(dt),method='number')
# Out:
# Plot with title “”

# %%
sp <- ggplot(dt, aes(x=age, y=num)) + 
  geom_point()
sp
# Out:
# plot without title

# %%
sp <- ggplot(dt, aes(x=thalach, y=num)) + 
  geom_point()
sp
# Out:
# plot without title
